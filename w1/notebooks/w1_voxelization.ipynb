# %% [markdown]
# # Voxelization Workshop
#
# In this workshop we will learn how to voxelize a geometry and construct a lattice from it.

# %% [markdown]
# ### 0. Initialization
# Importing all necessary libraries and specifying the inputs

# %%
#!conda env update -f ../environment.yml
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# typish-1.9.3         | 20 KB     |            |   0%
# typish-1.9.3         | 20 KB     | ########1  |  81%
# typish-1.9.3         | 20 KB     | ########## | 100%
#
# freeglut-3.2.1       | 149 KB    |            |   0%
# freeglut-3.2.1       | 149 KB    | ########## | 100%
# freeglut-3.2.1       | 149 KB    | ########## | 100%
#
# freetype-py-2.2.0    | 55 KB     |            |   0%
# freetype-py-2.2.0    | 55 KB     | ##8        |  29%
# freetype-py-2.2.0    | 55 KB     | ########## | 100%
# freetype-py-2.2.0    | 55 KB     | ########## | 100%
#
# planarity-3.0.0.5    | 95 KB     |            |   0%
# planarity-3.0.0.5    | 95 KB     | ########## | 100%
# planarity-3.0.0.5    | 95 KB     | ########## | 100%
#
# mpir-3.0.0           | 3.0 MB    |            |   0%
# mpir-3.0.0           | 3.0 MB    | 4          |   5%
# mpir-3.0.0           | 3.0 MB    | #####1     |  51%
# mpir-3.0.0           | 3.0 MB    | ########7  |  87%
# mpir-3.0.0           | 3.0 MB    | ########## | 100%
#
# compas-1.12.0        | 1.0 MB    |            |   0%
# compas-1.12.0        | 1.0 MB    | 1          |   2%
# compas-1.12.0        | 1.0 MB    | ########## | 100%
# compas-1.12.0        | 1.0 MB    | ########## | 100%
#
# libxml2-2.9.12       | 3.4 MB    |            |   0%
# libxml2-2.9.12       | 3.4 MB    | #8         |  18%
# libxml2-2.9.12       | 3.4 MB    | #####3     |  53%
# libxml2-2.9.12       | 3.4 MB    | ########9  |  90%
# libxml2-2.9.12       | 3.4 MB    | ########## | 100%
#
# contextlib2-0.5.5    | 10 KB     |            |   0%
# contextlib2-0.5.5    | 10 KB     | ########## | 100%
# contextlib2-0.5.5    | 10 KB     | ########## | 100%
#
# schema-0.7.4         | 19 KB     |            |   0%
# schema-0.7.4         | 19 KB     | ########## | 100%
# schema-0.7.4         | 19 KB     | ########## | 100%
#
# rtree-0.9.7          | 46 KB     |            |   0%
# rtree-0.9.7          | 46 KB     | ########## | 100%
# rtree-0.9.7          | 46 KB     | ########## | 100%
#
# numba-0.53.0         | 3.7 MB    |            |   0%
# numba-0.53.0         | 3.7 MB    | #          |  11%
# numba-0.53.0         | 3.7 MB    | ####3      |  43%
# numba-0.53.0         | 3.7 MB    | #######3   |  73%
# numba-0.53.0         | 3.7 MB    | ########## | 100%
# numba-0.53.0         | 3.7 MB    | ########## | 100%
#
# imageio-2.9.0        | 3.1 MB    |            |   0%
# imageio-2.9.0        | 3.1 MB    |            |   1%
# imageio-2.9.0        | 3.1 MB    | ##4        |  25%
# imageio-2.9.0        | 3.1 MB    | ###8       |  39%
# imageio-2.9.0        | 3.1 MB    | #######3   |  73%
# imageio-2.9.0        | 3.1 MB    | #########8 |  99%
# imageio-2.9.0        | 3.1 MB    | ########## | 100%
#
# sympy-1.9            | 11.5 MB   |            |   0%
# sympy-1.9            | 11.5 MB   |            |   0%
# sympy-1.9            | 11.5 MB   | 5          |   6%
# sympy-1.9            | 11.5 MB   | #3         |  13%
# sympy-1.9            | 11.5 MB   | #9         |  20%
# sympy-1.9            | 11.5 MB   | ##5        |  25%
# sympy-1.9            | 11.5 MB   | ###        |  31%
# sympy-1.9            | 11.5 MB   | ###9       |  39%
# sympy-1.9            | 11.5 MB   | ####5      |  45%
# sympy-1.9            | 11.5 MB   | #####1     |  52%
# sympy-1.9            | 11.5 MB   | #####7     |  58%
# sympy-1.9            | 11.5 MB   | ######3    |  64%
# sympy-1.9            | 11.5 MB   | #######    |  71%
# sympy-1.9            | 11.5 MB   | #######7   |  77%
# sympy-1.9            | 11.5 MB   | ########3  |  84%
# sympy-1.9            | 11.5 MB   | #########  |  90%
# sympy-1.9            | 11.5 MB   | #########7 |  97%
# sympy-1.9            | 11.5 MB   | ########## | 100%
#
# scipy-1.7.3          | 24.6 MB   |            |   0%
# scipy-1.7.3          | 24.6 MB   | 1          |   2%
# scipy-1.7.3          | 24.6 MB   | 4          |   5%
# scipy-1.7.3          | 24.6 MB   | 7          |   7%
# scipy-1.7.3          | 24.6 MB   | #          |  10%
# scipy-1.7.3          | 24.6 MB   | #3         |  13%
# scipy-1.7.3          | 24.6 MB   | #6         |  16%
# scipy-1.7.3          | 24.6 MB   | #9         |  19%
# scipy-1.7.3          | 24.6 MB   | ##2        |  22%
# scipy-1.7.3          | 24.6 MB   | ##5        |  26%
# scipy-1.7.3          | 24.6 MB   | ##8        |  28%
# scipy-1.7.3          | 24.6 MB   | ###1       |  31%
# scipy-1.7.3          | 24.6 MB   | ###4       |  35%
# scipy-1.7.3          | 24.6 MB   | ###7       |  38%
# scipy-1.7.3          | 24.6 MB   | ####       |  41%
# scipy-1.7.3          | 24.6 MB   | ####3      |  44%
# scipy-1.7.3          | 24.6 MB   | ####6      |  47%
# scipy-1.7.3          | 24.6 MB   | #####      |  50%
# scipy-1.7.3          | 24.6 MB   | #####3     |  53%
# scipy-1.7.3          | 24.6 MB   | #####6     |  56%
# scipy-1.7.3          | 24.6 MB   | #####9     |  59%
# scipy-1.7.3          | 24.6 MB   | ######2    |  62%
# scipy-1.7.3          | 24.6 MB   | ######5    |  66%
# scipy-1.7.3          | 24.6 MB   | ######8    |  69%
# scipy-1.7.3          | 24.6 MB   | #######3   |  73%
# scipy-1.7.3          | 24.6 MB   | #######8   |  78%
# scipy-1.7.3          | 24.6 MB   | ########3  |  84%
# scipy-1.7.3          | 24.6 MB   | ########9  |  89%
# scipy-1.7.3          | 24.6 MB   | #########4 |  94%
# scipy-1.7.3          | 24.6 MB   | #########9 |  99%
# scipy-1.7.3          | 24.6 MB   | ########## | 100%
#
# python-planarity-0.4 | 44 KB     |            |   0%
# python-planarity-0.4 | 44 KB     | ###6       |  36%
# python-planarity-0.4 | 44 KB     | ########## | 100%
# python-planarity-0.4 | 44 KB     | ########## | 100%
#
# compas_cgal-0.3.0    | 526 KB    |            |   0%
# compas_cgal-0.3.0    | 526 KB    | 3          |   3%
# compas_cgal-0.3.0    | 526 KB    | ########## | 100%
# compas_cgal-0.3.0    | 526 KB    | ########## | 100%
#
# cython-0.29.23       | 1.9 MB    |            |   0%
# cython-0.29.23       | 1.9 MB    |            |   1%
# cython-0.29.23       | 1.9 MB    | ####7      |  47%
# cython-0.29.23       | 1.9 MB    | ########## | 100%
# cython-0.29.23       | 1.9 MB    | ########## | 100%
#
# llvmlite-0.36.0      | 15.1 MB   |            |   0%
# llvmlite-0.36.0      | 15.1 MB   | 4          |   4%
# llvmlite-0.36.0      | 15.1 MB   | #2         |  12%
# llvmlite-0.36.0      | 15.1 MB   | ##1        |  21%
# llvmlite-0.36.0      | 15.1 MB   | ##9        |  29%
# llvmlite-0.36.0      | 15.1 MB   | ###7       |  37%
# llvmlite-0.36.0      | 15.1 MB   | ####8      |  48%
# llvmlite-0.36.0      | 15.1 MB   | #####7     |  57%
# llvmlite-0.36.0      | 15.1 MB   | ######5    |  66%
# llvmlite-0.36.0      | 15.1 MB   | #######2   |  73%
# llvmlite-0.36.0      | 15.1 MB   | ########   |  80%
# llvmlite-0.36.0      | 15.1 MB   | ########8  |  89%
# llvmlite-0.36.0      | 15.1 MB   | #########7 |  97%
# llvmlite-0.36.0      | 15.1 MB   | ########## | 100%
#
# libiconv-1.16        | 680 KB    |            |   0%
# libiconv-1.16        | 680 KB    | ########## | 100%
# libiconv-1.16        | 680 KB    | ########## | 100%
#
# jupyter-1.0.0        | 7 KB      |            |   0%
# jupyter-1.0.0        | 7 KB      | ########## | 100%
# jupyter-1.0.0        | 7 KB      | ########## | 100%
#
# bzip2-1.0.8          | 149 KB    |            |   0%
# bzip2-1.0.8          | 149 KB    | ########## | 100%
# bzip2-1.0.8          | 149 KB    | ########## | 100%
#
# boost-cpp-1.74.0     | 16.0 MB   |            |   0%
# boost-cpp-1.74.0     | 16.0 MB   | 5          |   5%
# boost-cpp-1.74.0     | 16.0 MB   | #2         |  13%
# boost-cpp-1.74.0     | 16.0 MB   | ##         |  20%
# boost-cpp-1.74.0     | 16.0 MB   | ##8        |  28%
# boost-cpp-1.74.0     | 16.0 MB   | ###6       |  36%
# boost-cpp-1.74.0     | 16.0 MB   | ####4      |  44%
# boost-cpp-1.74.0     | 16.0 MB   | #####1     |  52%
# boost-cpp-1.74.0     | 16.0 MB   | #####9     |  60%
# boost-cpp-1.74.0     | 16.0 MB   | ######7    |  68%
# boost-cpp-1.74.0     | 16.0 MB   | #######6   |  76%
# boost-cpp-1.74.0     | 16.0 MB   | ########4  |  84%
# boost-cpp-1.74.0     | 16.0 MB   | #########2 |  92%
# boost-cpp-1.74.0     | 16.0 MB   | ########## | 100%
#
# libxslt-1.1.33       | 501 KB    |            |   0%
# libxslt-1.1.33       | 501 KB    | 3          |   3%
# libxslt-1.1.33       | 501 KB    | ########## | 100%
# libxslt-1.1.33       | 501 KB    | ########## | 100%
#
# compas_view2-0.4.4   | 488 KB    |            |   0%
# compas_view2-0.4.4   | 488 KB    | 3          |   3%
# compas_view2-0.4.4   | 488 KB    | ########## | 100%
# compas_view2-0.4.4   | 488 KB    | ########## | 100%
#
# mpfr-4.1.0           | 450 KB    |            |   0%
# mpfr-4.1.0           | 450 KB    | #######8   |  78%
# mpfr-4.1.0           | 450 KB    | ########## | 100%
#
# typing_extensions-4. | 26 KB     |            |   0%
# typing_extensions-4. | 26 KB     | ########## | 100%
# typing_extensions-4. | 26 KB     | ########## | 100%
#
# pyside2-5.13.2       | 9.3 MB    |            |   0%
# pyside2-5.13.2       | 9.3 MB    | 5          |   6%
# pyside2-5.13.2       | 9.3 MB    | #9         |  19%
# pyside2-5.13.2       | 9.3 MB    | ###1       |  32%
# pyside2-5.13.2       | 9.3 MB    | ####5      |  45%
# pyside2-5.13.2       | 9.3 MB    | ######1    |  61%
# pyside2-5.13.2       | 9.3 MB    | #######4   |  74%
# pyside2-5.13.2       | 9.3 MB    | ########7  |  88%
# pyside2-5.13.2       | 9.3 MB    | ########## | 100%
#
# ezdxf-0.17           | 1.7 MB    |            |   0%
# ezdxf-0.17           | 1.7 MB    |            |   1%
# ezdxf-0.17           | 1.7 MB    | ######2    |  62%
# ezdxf-0.17           | 1.7 MB    | ########## | 100%
# ezdxf-0.17           | 1.7 MB    | ########## | 100%
#
# eigen-3.3.9          | 970 KB    |            |   0%
# eigen-3.3.9          | 970 KB    | 1          |   2%
# eigen-3.3.9          | 970 KB    | ########## | 100%
# eigen-3.3.9          | 970 KB    | ########## | 100%
#
# laspy-2.0.3          | 495 KB    |            |   0%
# laspy-2.0.3          | 495 KB    | #######4   |  74%
# laspy-2.0.3          | 495 KB    | ########## | 100%
#
# nptyping-1.4.4       | 16 KB     |            |   0%
# nptyping-1.4.4       | 16 KB     | ########## | 100%
# nptyping-1.4.4       | 16 KB     | ########## | 100%
#
# mpmath-1.2.1         | 437 KB    |            |   0%
# mpmath-1.2.1         | 437 KB    | ########## | 100%
# mpmath-1.2.1         | 437 KB    | ########## | 100%
#
# pyopengl-3.1.5       | 854 KB    |            |   0%
# pyopengl-3.1.5       | 854 KB    | ######1    |  62%
# pyopengl-3.1.5       | 854 KB    | ########## | 100%
#
# pycollada-0.7.2      | 84 KB     |            |   0%
# pycollada-0.7.2      | 84 KB     | #8         |  19%
# pycollada-0.7.2      | 84 KB     | ########## | 100%
# pycollada-0.7.2      | 84 KB     | ########## | 100%
#
# cgal-cpp-5.3         | 6.1 MB    |            |   0%
# cgal-cpp-5.3         | 6.1 MB    |            |   0%
# cgal-cpp-5.3         | 6.1 MB    | 4          |   4%
# cgal-cpp-5.3         | 6.1 MB    | #3         |  13%
# cgal-cpp-5.3         | 6.1 MB    | ##8        |  28%
# cgal-cpp-5.3         | 6.1 MB    | ####8      |  49%
# cgal-cpp-5.3         | 6.1 MB    | #######    |  70%
# cgal-cpp-5.3         | 6.1 MB    | #########  |  91%
# cgal-cpp-5.3         | 6.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\Users\\sebas\\.conda\\envs\\scds\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'w:\\Insync\\GDrive\\Main\\TU Delft\\Spatial Computing Minor\\w1\\condaenv.9ktrx6xt.requirements.txt']
# Pip subprocess output:
# Requirement already satisfied: ipyvtk-simple in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.1.4)
#
# Requirement already satisfied: itkwidgets in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.32.1)
#
# Requirement already satisfied: lbt-ladybug in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 3)) (0.25.95)
#
# Collecting lbt-ladybug
#
#   Downloading lbt_ladybug-0.25.96-py2.py3-none-any.whl (13 kB)
#
# Requirement already satisfied: mkdocs-material-extensions in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 4)) (1.0.3)
#
# Requirement already satisfied: mknotebooks in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.7.1)
#
# Requirement already satisfied: pyvista in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (0.28.1)
#
# Collecting pyvista
#
#   Using cached pyvista-0.32.1-py3-none-any.whl (1.4 MB)
#
# Requirement already satisfied: ipyvtklink in c:\users\sebas\.conda\envs\scds\lib\site-packages (from -r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 7)) (0.2.1)
#
# Requirement already satisfied: ipyevents>=0.8.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (2.0.1)
#
# Requirement already satisfied: ipycanvas>=0.5.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.9.1)
#
# Requirement already satisfied: ipywidgets in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (7.6.5)
#
# Requirement already satisfied: itk-core>=5.2.0.post2 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (5.2.1.post1)
#
# Requirement already satisfied: itk-filtering>=5.2.0.post2 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (5.2.1.post1)
#
# Requirement already satisfied: ipydatawidgets>=4.0.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (4.2.0)
#
# Requirement already satisfied: numpy in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (1.21.4)
#
# Requirement already satisfied: matplotlib in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (3.4.3)
#
# Requirement already satisfied: ipympl>=0.4.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.8.2)
#
# Requirement already satisfied: zstandard in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.16.0)
#
# Requirement already satisfied: colorcet in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (2.0.6)
#
# Requirement already satisfied: six in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (1.16.0)
#
# Requirement already satisfied: itk-meshtopolydata>=0.7.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.7.1)
#
# Collecting ladybug-comfort==0.12.34
#
#   Downloading ladybug_comfort-0.12.34-py2.py3-none-any.whl (122 kB)
#
# Collecting ladybug-core==0.39.25
#
#   Downloading ladybug_core-0.39.25-py2.py3-none-any.whl (235 kB)
#
# Requirement already satisfied: ladybug-geometry==1.23.19 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ladybug-core==0.39.25->ladybug-comfort==0.12.34->lbt-ladybug->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 3)) (1.23.19)
#
# Requirement already satisfied: click==7.1.2 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ladybug-core==0.39.25->ladybug-comfort==0.12.34->lbt-ladybug->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 3)) (7.1.2)
#
# Requirement already satisfied: markdown>=3.3.3 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (3.3.4)
#
# Requirement already satisfied: mkdocs>=1.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (1.2.3)
#
# Requirement already satisfied: gitpython in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (3.1.24)
#
# Requirement already satisfied: nbconvert>=6.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (6.2.0)
#
# Requirement already satisfied: jupyter-client in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (7.0.6)
#
# Requirement already satisfied: imageio in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (2.10.3)
#
# Requirement already satisfied: typing-extensions in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (4.0.0)
#
# Requirement already satisfied: meshio<5.0,>=4.0.3 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (4.4.6)
#
# Requirement already satisfied: pillow in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (8.4.0)
#
# Requirement already satisfied: vtk in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (9.1.0)
#
# Requirement already satisfied: appdirs in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (1.4.4)
#
# Requirement already satisfied: scooby>=0.5.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (0.5.7)
#
# Requirement already satisfied: traittypes>=0.2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipydatawidgets>=4.0.1->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.2.1)
#
# Requirement already satisfied: ipykernel>=4.7 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipympl>=0.4.1->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (6.5.0)
#
# Requirement already satisfied: ipython>=4.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (7.29.0)
#
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (5.1.3)
#
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.2.0)
#
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (3.5.2)
#
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (1.0.2)
#
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (5.1.1)
#
# Requirement already satisfied: itk-numerics==5.2.1.post1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from itk-filtering>=5.2.0.post2->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (5.2.1.post1)
#
# Requirement already satisfied: cycler>=0.10 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from matplotlib->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.11.0)
#
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from matplotlib->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (3.0.5)
#
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from matplotlib->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (2.8.2)
#
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from matplotlib->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (1.3.2)
#
# Requirement already satisfied: mergedeep>=1.3.4 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (1.3.4)
#
# Requirement already satisfied: PyYAML>=3.10 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (6.0)
#
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (3.0.3)
#
# Requirement already satisfied: watchdog>=2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (2.1.6)
#
# Requirement already satisfied: importlib-metadata>=3.10 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (4.8.2)
#
# Requirement already satisfied: packaging>=20.5 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (21.0)
#
# Requirement already satisfied: ghp-import>=1.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (2.0.2)
#
# Requirement already satisfied: pyyaml-env-tag>=0.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.1)
#
# Requirement already satisfied: jupyter-core in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (4.9.1)
#
# Requirement already satisfied: defusedxml in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.7.1)
#
# Requirement already satisfied: jupyterlab-pygments in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.1.2)
#
# Requirement already satisfied: pygments>=2.4.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (2.10.0)
#
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (1.5.0)
#
# Requirement already satisfied: testpath in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.5.0)
#
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.5.5)
#
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.3)
#
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.8.4)
#
# Requirement already satisfied: bleach in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (4.1.0)
#
# Requirement already satisfied: param>=1.7.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from colorcet->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (1.12.0)
#
# Requirement already satisfied: pyct>=0.4.4 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from colorcet->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.4.8)
#
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from gitpython->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (4.0.9)
#
# Requirement already satisfied: pyzmq>=13 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jupyter-client->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (22.3.0)
#
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jupyter-client->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (1.5.1)
#
# Requirement already satisfied: tornado>=4.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jupyter-client->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (6.1)
#
# Requirement already satisfied: wslink>=1.0.4 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (1.1.0)
#
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (5.0.0)
#
# Requirement already satisfied: zipp>=0.5 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from importlib-metadata>=3.10->mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (3.6.0)
#
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipykernel>=4.7->ipympl>=0.4.1->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (0.1.3)
#
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipykernel>=4.7->ipympl>=0.4.1->itkwidgets->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 2)) (1.5.1)
#
# Requirement already satisfied: setuptools>=18.5 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (58.5.3)
#
# Requirement already satisfied: jedi>=0.16 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.18.0)
#
# Requirement already satisfied: backcall in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.2.0)
#
# Requirement already satisfied: decorator in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (5.1.0)
#
# Requirement already satisfied: pickleshare in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.7.5)
#
# Requirement already satisfied: colorama in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.4.4)
#
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (3.0.22)
#
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from Jinja2>=2.10.1->mkdocs>=1.1->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (2.0.1)
#
# Requirement already satisfied: pywin32>=1.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jupyter-core->nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (302)
#
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from nbformat>=4.2.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (4.2.1)
#
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (6.4.5)
#
# Requirement already satisfied: aiohttp in c:\users\sebas\.conda\envs\scds\lib\site-packages (from wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (3.8.0)
#
# Requirement already satisfied: webencodings in c:\users\sebas\.conda\envs\scds\lib\site-packages (from bleach->nbconvert>=6.0.0->mknotebooks->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 5)) (0.5.1)
#
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.8.2)
#
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (21.2.0)
#
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.18.0)
#
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (5.4.0)
#
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.12.1)
#
# Requirement already satisfied: argon2-cffi in c:\users\sebas\.conda\envs\scds\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (21.1.0)
#
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (1.8.0)
#
# Requirement already satisfied: prometheus-client in c:\users\sebas\.conda\envs\scds\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.12.0)
#
# Requirement already satisfied: wcwidth in c:\users\sebas\.conda\envs\scds\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (0.2.5)
#
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (1.7.2)
#
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (5.2.0)
#
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (1.2.0)
#
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (1.2.0)
#
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (2.0.7)
#
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (4.0.1)
#
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (1.1.5)
#
# Requirement already satisfied: idna>=2.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->wslink>=1.0.4->vtk->pyvista->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 6)) (3.3)
#
# Requirement already satisfied: cffi>=1.0.0 in c:\users\sebas\.conda\envs\scds\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (1.15.0)
#
# Requirement already satisfied: pycparser in c:\users\sebas\.conda\envs\scds\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyvtk-simple->-r w:\Insync\GDrive\Main\TU Delft\Spatial Computing Minor\w1\condaenv.9ktrx6xt.requirements.txt (line 1)) (2.21)
#
# Installing collected packages: ladybug-core, ladybug-comfort, pyvista, lbt-ladybug
#
#   Attempting uninstall: ladybug-core
#
#     Found existing installation: ladybug-core 0.39.24
#
#     Uninstalling ladybug-core-0.39.24:
#
#       Successfully uninstalled ladybug-core-0.39.24
#
#   Attempting uninstall: ladybug-comfort
#
#     Found existing installation: ladybug-comfort 0.12.33
#
#     Uninstalling ladybug-comfort-0.12.33:
#
#       Successfully uninstalled ladybug-comfort-0.12.33
#
#   Attempting uninstall: pyvista
#
#     Found existing installation: pyvista 0.28.1
#
#     Uninstalling pyvista-0.28.1:
#
#       Successfully uninstalled pyvista-0.28.1
#
#   Attempting uninstall: lbt-ladybug
#
#     Found existing installation: lbt-ladybug 0.25.95
#
#     Uninstalling lbt-ladybug-0.25.95:
#
#       Successfully uninstalled lbt-ladybug-0.25.95
#
# Successfully installed ladybug-comfort-0.12.34 ladybug-core-0.39.25 lbt-ladybug-0.25.96 pyvista-0.32.1
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate scds
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
import os
import topogenesis as tg
import trimesh as tm
import numpy as np
import pyvista as pv
pv.set_jupyter_backend("ipyvtklink")

# %%
vs = 10
unit = [vs, vs, vs]
mesh_path = os.path.relpath('../data/optional_envelope.obj')

# %% [markdown]
# ## 1. Input Mesh

# %%
# load the mesh from file
mesh = tm.load(mesh_path)
# Check if the mesh is watertight
print(mesh.is_watertight)
# Out:
# True

# %%
# convert trimesh to pv_mesh
def tri_to_pv(tri_mesh):
    faces = np.pad(tri_mesh.faces, ((0, 0),(1,0)), 'constant', constant_values=3)
    pv_mesh = pv.PolyData(tri_mesh.vertices, faces)
    return pv_mesh

# Visualize the mesh using pyvista plotter
#######

# initiating the plotter
p = pv.Plotter()

# adding the base mesh: light blue
p.add_mesh(tri_to_pv(mesh), color='#abd8ff')

# plotting
p.show()
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %% [markdown]
# ## 2. Voxelize the Mesh

# %%
# initialize the base lattice
base_lattice = tg.lattice(mesh.bounds, unit=unit, default_value=1, dtype=int)

# check which voxel centroids is inside the mesh
interior_condition = mesh.contains(base_lattice.centroids)

# reshape the interior condition to the shape of the base_lattice
interior_array = interior_condition.reshape(base_lattice.shape)

# convert the interior array into a lattice
interior_lattice = tg.to_lattice(interior_array, base_lattice.minbound, base_lattice.unit)

# %%
# convert trimesh to pv_mesh
def tri_to_pv(tri_mesh):
    faces = np.pad(tri_mesh.faces, ((0, 0),(1,0)), 'constant', constant_values=3)
    pv_mesh = pv.PolyData(tri_mesh.vertices, faces)
    return pv_mesh

# Visualize the voxelization using pyvista plotter
#####

# initiating the plotter
p = pv.Plotter()

# fast visualization of the lattice
interior_lattice.fast_vis(p)

# adding the base mesh: light blue
p.add_mesh(tri_to_pv(mesh), color='#abd8ff', opacity=0.1)

# plotting
p.show()
# Out:
# C:\Users\sebas\.conda\envs\scds\lib\site-packages\pyvista\core\dataset.py:1332: PyvistaDeprecationWarning: Use of `cell_arrays` is deprecated. Use `cell_data` instead.
#   warnings.warn(
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %% [markdown]
# ## 3. Saving the lattice to CSV

# %%
csv_path = os.path.relpath('../data/voxelized_envelope.csv')
interior_lattice.to_csv(csv_path)

# %% [markdown]
# ### Credits

# %%
__author__ = "Shervin Azadi"
__license__ = "MIT"
__version__ = "1.0"
__url__ = "https://github.com/shervinazadi/spatial_computing_workshops"
__summary__ = "Spatial Computing Design Studio Workshop on Voxelization"
